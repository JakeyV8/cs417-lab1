# %% [markdown]
# <a href="https://colab.research.google.com/github/JakeyV8/cs417-lab1/blob/main/CS417_Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CS 417 - Lab 1: Google Colab Introduction
#
# **Date:** 1-22-2026
#
# This notebook demonstrates basic Python concepts including:
#
# - Print statements
#
# - Variables
#
# - Basic arithmetic operations
#
# - String formatting

# %%
print("Welcome to Google Colab!")

print("Python makes programming fun!")
# Out:
# Welcome to Google Colab!
# Python makes programming fun!

# %%
favorite_food = "Seafood"

favorite_number = 13

favorite_color = "purple"
print("My favorite food is:", favorite_food)

print("My favorite number is:", favorite_number)

print("My favorite color is:", favorite_color)
# Out:
# My favorite food is: Seafood
# My favorite number is: 13
# My favorite color is: purple

# %%
favorite_animal = "Monkey"
favorite_sport = "Skiing"
print("There are", 2*5 ,"",favorite_animal,"'s", favorite_sport)
# Out:
# There are 10  Monkey 's Skiing
